# %%
from Model.Generator import Generator
import Reducer
import RunGenRed
import math
import random
from pprint import pprint
import shutil
from subprocess import *
import matplotlib.pyplot as plt
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5329640a5b67> in <module>()
# ----> 1 from Model.Generator import Generator
#       2 import Reducer
#       3 import RunGenRed
#       4 import math
#       5 import random
#
# ModuleNotFoundError: No module named 'Model'
